# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('encoded_db.xlsx')
df
# Out:
#        Unnamed: 0  index              date Encoded Products  \
# 0               0      4       02 ene 2022      Producto 11
# 1               1      5       02 ene 2022       Producto 6
# 2               2      6       02 ene 2022      Producto 24
# 3               3      7       02 ene 2022      Producto 15
# 4               4      8       02 ene 2022       Producto 9
# ...           ...    ...               ...              ...
# 26459       26459   4317       31 dic 2023     Producto 273
# 26460       26460   4318       31 dic 2023     Producto 273
# 26461       26461   4319       31 dic 2023     Producto 273
# 26462       26462   4320       31 dic 2023     Producto 273
# 26463       26463   4321       31 dic 2023     Producto 273
#
#        Cadereyta total $  Cadereyta ctdad  Coahuila total $  Coahuila ctdad  \
# 0                   0.00              0.0             0.000             0.0
# 1                   0.00              0.0             0.000             0.0
# ...

# %%
df = df.drop(df.index[:3])

# %%
df['fecha'] = np.nan

# %%
df
# Out:
#             Unnamed: 0 Total Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 3          01 abr 2022   NaN        NaN  293340.355       52.5  33364.555
# 4           Producto 1   NaN        NaN   15389.535        3.5        NaN
# 5           Producto 2   NaN        NaN         NaN        NaN        NaN
# 6           Producto 3   NaN        NaN    37488.08          7        NaN
# 7           Producto 4   NaN        NaN         NaN        NaN        NaN
# ...                ...   ...        ...         ...        ...        ...
# 3613       Producto 42   NaN        NaN         NaN        NaN        NaN
# 3614       Producto 23   NaN        NaN         NaN        NaN        NaN
# 3615       Producto 58   NaN        NaN         NaN        NaN        NaN
# 3616      Producto 104   NaN        NaN         NaN        NaN        NaN
# 3617       Producto 60   NaN        NaN         NaN        NaN        NaN
#
#      Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 14 Unnamed: 15  \
# ...

# %%
import re
pattern = r'\s*\d{2}\s+(ene|feb|mar|abr|may|jun|jul|ago|sep|oct|nov|dic)\s+\d{4}\s*'
for i in range(len(df)):
    if re.match(pattern, str(df.iloc[i,0])):
        fecha = df.iloc[i,0]
    else:
        df.iloc[i,-1] = fecha
# Out:
# C:\Users\jesus\AppData\Local\Temp\ipykernel_16132\550149270.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '     01 abr 2022' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.iloc[i,-1] = fecha

# %%
df
# Out:
#             Unnamed: 0 Total Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 3          01 abr 2022   NaN        NaN  293340.355       52.5  33364.555
# 4           Producto 1   NaN        NaN   15389.535        3.5        NaN
# 5           Producto 2   NaN        NaN         NaN        NaN        NaN
# 6           Producto 3   NaN        NaN    37488.08          7        NaN
# 7           Producto 4   NaN        NaN         NaN        NaN        NaN
# ...                ...   ...        ...         ...        ...        ...
# 3613       Producto 42   NaN        NaN         NaN        NaN        NaN
# 3614       Producto 23   NaN        NaN         NaN        NaN        NaN
# 3615       Producto 58   NaN        NaN         NaN        NaN        NaN
# 3616      Producto 104   NaN        NaN         NaN        NaN        NaN
# 3617       Producto 60   NaN        NaN         NaN        NaN        NaN
#
#      Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 14 Unnamed: 15  \
# ...

# %%
df = df.dropna(subset=['fecha'])

# %%
df.fecha.unique()
# Out:
# array(['     01 abr 2022', '     02 abr 2022', '     03 abr 2022',
#        '     04 abr 2022', '     05 abr 2022', '     06 abr 2022',
#        '     07 abr 2022', '     08 abr 2022', '     09 abr 2022',
#        '     10 abr 2022', '     11 abr 2022', '     12 abr 2022',
#        '     13 abr 2022', '     14 abr 2022', '     15 abr 2022',
#        '     16 abr 2022', '     17 abr 2022', '     18 abr 2022',
#        '     19 abr 2022', '     20 abr 2022', '     21 abr 2022',
#        '     22 abr 2022', '     23 abr 2022', '     24 abr 2022',
#        '     25 abr 2022', '     26 abr 2022', '     27 abr 2022',
#        '     28 abr 2022', '     29 abr 2022', '     30 abr 2022',
#        '     01 may 2022', '     02 may 2022', '     03 may 2022',
#        '     04 may 2022', '     05 may 2022', '     06 may 2022',
#        '     07 may 2022', '     08 may 2022', '     09 may 2022',
#        '     10 may 2022', '     11 may 2022', '     12 may 2022',
# ...

# %%
df['fecha'] = df['fecha'].str.strip()
df.fecha.unique()
# Out:
# C:\Users\jesus\AppData\Local\Temp\ipykernel_16132\3829434174.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fecha'] = df['fecha'].str.strip()
# array(['01 abr 2022', '02 abr 2022', '03 abr 2022', '04 abr 2022',
#        '05 abr 2022', '06 abr 2022', '07 abr 2022', '08 abr 2022',
#        '09 abr 2022', '10 abr 2022', '11 abr 2022', '12 abr 2022',
#        '13 abr 2022', '14 abr 2022', '15 abr 2022', '16 abr 2022',
#        '17 abr 2022', '18 abr 2022', '19 abr 2022', '20 abr 2022',
#        '21 abr 2022', '22 abr 2022', '23 abr 2022', '24 abr 2022',
#        '25 abr 2022', '26 abr 2022', '27 abr 2022', '28 abr 2022',
#        '29 abr 2022', '30 abr 2022', '01 may 2022', '02 may 2022',
# ...

# %%
import pandas as pd

# Supongamos que tienes un DataFrame llamado df

# Renombra las columnas
df = df.rename(columns={'Unnamed: 0':'product', 'Total':'Cadereyta total libreImpuestos', 'Unnamed: 2': 'Cadereyta Ctdad Ordenada', 'Unnamed: 3': 'Coahuila total libreImpuestos', 'Unnamed: 4': 'Coahuila Ctdad Ordenada',
       'Unnamed: 5': 'Durango total libreImpuestos', 'Unnamed: 6': 'Durango Ctdad Ordenada', 'Unnamed: 7':'Expos F total libreImpuestos', 'Unnamed: 8': 'Expos F Ctdad Ordenada', 'Unnamed: 9': 'Laredo total libreImpuestos',
       'Unnamed: 10': 'Laredo Ctdad Ordenada', 'Unnamed: 11': 'Monterrey total libreImpuestos', 'Unnamed: 12':'Monterrey Ctdad Ordenada', 'Unnamed: 13': 'Online total libreImpuestos',
       'Unnamed: 14': 'Online Ctdad Ordenada', 'Unnamed: 15': 'Queretaro total libreImpuestos', 'Unnamed: 16': 'Queretaro Ctdad Ordenada', 'Unnamed: 17': 'Reynosa total libreImpuestos',
       'Unnamed: 18': 'Reynosa Ctdad Ordenada', 'Unnamed: 19': 'San Luis total libreImpuestos', 'Unnamed: 20': 'San Luis Ctdad Ordenada', 'Unnamed: 21':'Total libreImpuestos',
       'Unnamed: 22': 'Ctdad Ordenada'})

# Muestra el DataFrame con las columnas renombradas
print(df)
# Out:
#            product Cadereyta total libreImpuestos Cadereyta Ctdad Ordenada  \
# 4       Producto 1                            NaN                      NaN
# 5       Producto 2                            NaN                      NaN
# 6       Producto 3                            NaN                      NaN
# 7       Producto 4                            NaN                      NaN
# 8       Producto 5                            NaN                      NaN
# ...            ...                            ...                      ...
# 3613   Producto 42                            NaN                      NaN
# 3614   Producto 23                            NaN                      NaN
# 3615   Producto 58                            NaN                      NaN
# 3616  Producto 104                            NaN                      NaN
# 3617   Producto 60                            NaN                      NaN
#
#      Coahuila total libreImpuestos Coahuila Ctdad Ordenada  \
# ...

# %%
df
# Out:
#            product Cadereyta total libreImpuestos Cadereyta Ctdad Ordenada  \
# 4       Producto 1                            NaN                      NaN
# 5       Producto 2                            NaN                      NaN
# 6       Producto 3                            NaN                      NaN
# 7       Producto 4                            NaN                      NaN
# 8       Producto 5                            NaN                      NaN
# ...            ...                            ...                      ...
# 3613   Producto 42                            NaN                      NaN
# 3614   Producto 23                            NaN                      NaN
# 3615   Producto 58                            NaN                      NaN
# 3616  Producto 104                            NaN                      NaN
# 3617   Producto 60                            NaN                      NaN
#
#      Coahuila total libreImpuestos Coahuila Ctdad Ordenada  \
# ...

# %%
def cambiar_formato_fecha(fecha):
    partes = fecha.split()  # Dividir la fecha en partes: ['01', 'ene', '2024']
    if partes[1] == 'abr':
        nuevo_formato = partes[0] + '-' + '04' + '-' + partes[2]  # Construir el nuevo formato: '01-abr-2024'
    elif partes[1] == 'may':
        nuevo_formato = partes[0] + '-' + '05' + '-' + partes[2]  # Construir el nuevo formato: '01-may-2024'
    elif partes[1] == 'jun':
        nuevo_formato = partes[0] + '-' + '06' + '-' + partes[2]  # Construir el nuevo formato: '01-jun-2024'
    return nuevo_formato

# Aplicar la función para cambiar el formato de las fechas a la columna 'fecha'
df['fecha'] = df['fecha'].apply(cambiar_formato_fecha)

# %%
df['fecha'] = pd.to_datetime(df['fecha'], format='%d-%m-%Y')

# %%
df
# Out:
#            product Cadereyta total libreImpuestos Cadereyta Ctdad Ordenada  \
# 4       Producto 1                            NaN                      NaN
# 5       Producto 2                            NaN                      NaN
# 6       Producto 3                            NaN                      NaN
# 7       Producto 4                            NaN                      NaN
# 8       Producto 5                            NaN                      NaN
# ...            ...                            ...                      ...
# 3613   Producto 42                            NaN                      NaN
# 3614   Producto 23                            NaN                      NaN
# 3615   Producto 58                            NaN                      NaN
# 3616  Producto 104                            NaN                      NaN
# 3617   Producto 60                            NaN                      NaN
#
#      Coahuila total libreImpuestos Coahuila Ctdad Ordenada  \
# ...

# %%
df = df.dropna(subset=['product'])

# %%
df = df.reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3078 entries, 0 to 3077
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   product                         3078 non-null   object
#  1   Cadereyta total libreImpuestos  72 non-null     object
#  2   Cadereyta Ctdad Ordenada        72 non-null     object
#  3   Coahuila total libreImpuestos   673 non-null    object
#  4   Coahuila Ctdad Ordenada         673 non-null    object
#  5   Durango total libreImpuestos    27 non-null     object
#  6   Durango Ctdad Ordenada          27 non-null     object
#  7   Expos F total libreImpuestos    43 non-null     object
#  8   Expos F Ctdad Ordenada          43 non-null     object
#  9   Laredo total libreImpuestos     275 non-null    object
#  10  Laredo Ctdad Ordenada           275 non-null    object
#  11  Monterrey total libreImpuestos  1877 non-null   object
# ...

# %%
df['product'].unique()
# Out:
# array(['Producto 1', 'Producto 2', 'Producto 3', 'Producto 4',
#        'Producto 5', 'Producto 6', 'Producto 7', 'Producto 8',
#        'Producto 9', 'Producto 10', 'Producto 11', 'Producto 12',
#        'Producto 13', 'Producto 14', 'Producto 15', 'Producto 16',
#        'Producto 17', 'Producto 18', 'Producto 19', 'Producto 20',
#        'Producto 21', 'Producto 22', 'Producto 23', 'Producto 24',
#        'Producto 25', 'Producto 26', 'Producto 27', 'Producto 28',
#        'Producto 29', 'Producto 30', 'Producto 31', 'Producto 32',
#        'Producto 33', 'Producto 34', 'Producto 35', 'Producto 36',
#        'Producto 37', 'Producto 38', 'Producto 39', 'Producto 40',
#        'Producto 41', 'Producto 42', 'Producto 43', 'Producto 44',
#        'Producto 45', 'Producto 46', 'Producto 47', 'Producto 48',
#        'Producto 49', 'Producto 50', 'Producto 51', 'Producto 52',
#        'Producto 53', 'Producto 54', 'Producto 55', 'Producto 56',
# ...

# %%
df.to_csv('dataCleanAhoraSi.csv', index=False)

# %%
nulos = []
for i in range(1, 312):

    nulo = df[df['product'] == 'Producto '+str(i)].shape[0]
    nulos.append(nulo)

# %%
valor_maximo = max(nulos)
print(valor_maximo)
indice_minimo = nulos.index(valor_maximo)
print(indice_minimo)
# Out:
# 89
# 11

# %%
df[df['product'] == 'Producto 12']
# Out:
#           product Cadereyta total libreImpuestos Cadereyta Ctdad Ordenada  \
# 11    Producto 12                            NaN                      NaN
# 35    Producto 12                            NaN                      NaN
# 71    Producto 12                            NaN                      NaN
# 105   Producto 12                            NaN                      NaN
# 136   Producto 12                            NaN                      NaN
# ...           ...                            ...                      ...
# 2908  Producto 12                            NaN                      NaN
# 2948  Producto 12                            NaN                      NaN
# 2986  Producto 12                            NaN                      NaN
# 3024  Producto 12                      11013.485                      3.5
# 3055  Producto 12                            NaN                      NaN
#
#      Coahuila total libreImpuestos Coahuila Ctdad Ordenada  \
# ...

# %%
df[df['product'] == 'Producto 12'].shape[0]
# Out:
# 89

# %%
df[['product', 'fecha', 'Cadereyta total libreImpuestos', 'Cadereyta Ctdad Ordenada']]
# Out:
#            product      fecha Cadereyta total libreImpuestos  \
# 0       Producto 1 2022-04-01                            NaN
# 1       Producto 2 2022-04-01                            NaN
# 2       Producto 3 2022-04-01                            NaN
# 3       Producto 4 2022-04-01                            NaN
# 4       Producto 5 2022-04-01                            NaN
# ...            ...        ...                            ...
# 3073   Producto 42 2022-06-30                            NaN
# 3074   Producto 23 2022-06-30                            NaN
# 3075   Producto 58 2022-06-30                            NaN
# 3076  Producto 104 2022-06-30                            NaN
# 3077   Producto 60 2022-06-30                            NaN
#
#      Cadereyta Ctdad Ordenada
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# ...

# %%
suma_por_fecha = df.groupby('fecha').sum()

# %% [markdown]
# # Sarimax

# %%
product = df[df['product']=='Producto 12']
product
# Out:
#           product Cadereyta total libreImpuestos Cadereyta Ctdad Ordenada  \
# 11    Producto 12                            NaN                      NaN
# 35    Producto 12                            NaN                      NaN
# 71    Producto 12                            NaN                      NaN
# 105   Producto 12                            NaN                      NaN
# 136   Producto 12                            NaN                      NaN
# ...           ...                            ...                      ...
# 2908  Producto 12                            NaN                      NaN
# 2948  Producto 12                            NaN                      NaN
# 2986  Producto 12                            NaN                      NaN
# 3024  Producto 12                      11013.485                      3.5
# 3055  Producto 12                            NaN                      NaN
#
#      Coahuila total libreImpuestos Coahuila Ctdad Ordenada  \
# ...

# %%
product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 89 entries, 11 to 3055
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   product                         89 non-null     object
#  1   Cadereyta total libreImpuestos  2 non-null      object
#  2   Cadereyta Ctdad Ordenada        2 non-null      object
#  3   Coahuila total libreImpuestos   42 non-null     object
#  4   Coahuila Ctdad Ordenada         42 non-null     object
#  5   Durango total libreImpuestos    4 non-null      object
#  6   Durango Ctdad Ordenada          4 non-null      object
#  7   Expos F total libreImpuestos    3 non-null      object
#  8   Expos F Ctdad Ordenada          3 non-null      object
#  9   Laredo total libreImpuestos     22 non-null     object
#  10  Laredo Ctdad Ordenada           22 non-null     object
#  11  Monterrey total libreImpuestos  73 non-null     object
# ...

# %%
# Supongamos que df es tu DataFrame original con una columna llamada 'timestamp'
# Asegúrate de ordenar el DataFrame por la columna de timestamp
product = product.sort_values('fecha')

# Crea un nuevo DataFrame con un rango de fechas desde la fecha mínima hasta la fecha máxima en tu DataFrame original
fecha_min = product['fecha'].min()
fecha_max = product['fecha'].max()
rango_fechas = pd.date_range(start=fecha_min, end=fecha_max, freq='D')
df_rango_fechas = pd.DataFrame({'fecha': rango_fechas})

# Fusiona el nuevo DataFrame con tu DataFrame original
product = pd.merge(df_rango_fechas, product, on='fecha', how='left')

# Rellena los valores NaN con las fechas faltantes
product['fecha'] = product['fecha'].fillna(method='ffill')
# Out:
# C:\Users\jesus\AppData\Local\Temp\ipykernel_16132\2782430795.py:15: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   product['fecha'] = product['fecha'].fillna(method='ffill')

# %%
product
# Out:
#         fecha      product Cadereyta total libreImpuestos  \
# 0  2022-04-01  Producto 12                            NaN
# 1  2022-04-02  Producto 12                            NaN
# 2  2022-04-03  Producto 12                            NaN
# 3  2022-04-04  Producto 12                            NaN
# 4  2022-04-05  Producto 12                            NaN
# ..        ...          ...                            ...
# 86 2022-06-26  Producto 12                            NaN
# 87 2022-06-27  Producto 12                            NaN
# 88 2022-06-28  Producto 12                            NaN
# 89 2022-06-29  Producto 12                      11013.485
# 90 2022-06-30  Producto 12                            NaN
#
#    Cadereyta Ctdad Ordenada Coahuila total libreImpuestos  \
# 0                       NaN                      58672.32
# 1                       NaN                           NaN
# 2                       NaN                           NaN
# ...

# %%
product.fillna(0, inplace=True)
# Out:
# C:\Users\jesus\AppData\Local\Temp\ipykernel_16132\2296660442.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   product.fillna(0, inplace=True)

# %%
#product['fecha'] = pd.to_datetime(product['fecha'], format='%Y-%m-%d')
product['fecha'] = pd.to_datetime(product['fecha'], infer_datetime_format=True)
product12 = product.set_index(['fecha'])
product12 = product12['Ctdad Ordenada']
#product12.index = pd.DatetimeIndex(product12.index).to_period('D')
product12.head()
# Out:
# C:\Users\jesus\AppData\Local\Temp\ipykernel_16132\3586454341.py:2: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   product['fecha'] = pd.to_datetime(product['fecha'], infer_datetime_format=True)
# fecha
# 2022-04-01    17.5
# 2022-04-02    17.5
# 2022-04-03    17.5
# 2022-04-04    28.0
# 2022-04-05    31.5
# Name: Ctdad Ordenada, dtype: float64

# %%
product12.plot()
# Out:
# <Axes: xlabel='fecha'>

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(10, 6))
plt.plot(product12, color='blue', linestyle='-')
plt.title('Producto 12')
plt.xlabel('Fecha')
plt.ylabel('Ctad ordenada')
plt.grid(True)
plt.show()

# %%
print(product12.index.freq)
# Out:
# None

# %%
import pandas as pd
from statsmodels.tsa.seasonal import seasonal_decompose

decompose_data = seasonal_decompose(product12, model="additive")
decompose_data.plot()

# %%
plt.figure(figsize=(10, 6))
seasonality=decompose_data.seasonal
seasonality.plot(color='green')
# Out:
# <Axes: xlabel='fecha'>

# %%
from statsmodels.tsa.stattools import adfuller
dftest = adfuller(product12, autolag = 'AIC')
print("1. ADF : ",dftest[0])
print("2. P-Value : ", dftest[1])
print("3. Num Of Lags : ", dftest[2])
print("4. Num Of Observations Used For ADF Regression and Critical Values Calculation :", dftest[3])
print("5. Critical Values :")
for key, val in dftest[4].items():
    print("\t",key, ": ", val)
# Out:
# 1. ADF :  -9.543405213217465
# 2. P-Value :  2.6888309310024123e-16
# 3. Num Of Lags :  0
# 4. Num Of Observations Used For ADF Regression and Critical Values Calculation : 90
# 5. Critical Values :
# 	 1% :  -3.505190196159122
# 	 5% :  -2.894232085048011
# 	 10% :  -2.5842101234567902

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

lag_acf = acf(product12, nlags=20)
lag_pacf = pacf(product12, nlags=20, method='ols')

fig, ax = plt.subplots(1,2,figsize=(16,4))
plot_acf(lag_acf, ax=ax[0])
plot_pacf(lag_pacf, ax=ax[1])


plt.show()

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(product12, test_size = 0.10, shuffle = False)

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing, Holt
train_smoth = train.copy()
train_smoth = SimpleExpSmoothing(np.asarray(train))

train_smoth._index = pd.to_datetime(train.index)
train_smoth = train_smoth.fit(smoothing_level=0.3).fittedvalues

train_new = pd.Series(train_smoth, index=train.index)
# Out:
# c:\Users\jesus\anaconda3\lib\site-packages\pandas\util\_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing, Holt
test_smoth = test.copy()
test_smoth = SimpleExpSmoothing(np.asarray(test))

test_smoth._index = pd.to_datetime(test.index)
test_smoth = test_smoth.fit(smoothing_level=0.3).fittedvalues

test_new = pd.Series(test_smoth, index=test.index)
# Out:
# c:\Users\jesus\anaconda3\lib\site-packages\pandas\util\_decorators.py:213: EstimationWarning: Model has no free parameters to estimate. Set optimized=False to suppress this warning
#   return func(*args, **kwargs)

# %%
train
# Out:
# fecha
# 2022-04-01    17.5
# 2022-04-02    17.5
# 2022-04-03    17.5
# 2022-04-04    28.0
# 2022-04-05    31.5
#               ...
# 2022-06-16    24.5
# 2022-06-17     7.0
# 2022-06-18    17.5
# 2022-06-19    24.5
# 2022-06-20    24.5
# Name: Ctdad Ordenada, Length: 81, dtype: float64

# %%
train_new
# Out:
# fecha
# 2022-04-01    17.500000
# 2022-04-02    17.500000
# 2022-04-03    17.500000
# 2022-04-04    17.500000
# 2022-04-05    20.650000
#                 ...
# 2022-06-16    13.928590
# 2022-06-17    17.100013
# 2022-06-18    14.070009
# 2022-06-19    15.099006
# 2022-06-20    17.919304
# Length: 81, dtype: float64

# %%
plt.plot(train_new, color='green')

# %%
plt.plot(train, label='Train')

# %%
import statsmodels.api as sm

model=sm.tsa.statespace.SARIMAX(train_new,order=(1, 2, 1),seasonal_order=(2,3,3,7))
results=model.fit()
predictions = results.predict(start='2022-06-21', end='2022-06-30')
# Out:
# c:\Users\jesus\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\jesus\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\jesus\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'

# %%
pip install skforecast
# Out:
# ...
#   Using cached skforecast-0.11.0-py3-none-any.whl (424 kB)
# ...
#   Using cached optuna-3.4.0-py3-none-any.whl (409 kB)
# ...
#   Using cached pandas-2.1.4-cp310-cp310-win_amd64.whl (10.7 MB)
# ...
#   Using cached alembic-1.13.1-py3-none-any.whl (233 kB)
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.1
#     Uninstalling pandas-2.2.1:
#       Successfully uninstalled pandas-2.2.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Acceso denegado: 'C:\\Users\\jesus\\anaconda3\\Lib\\site-packages\\~andas.libs\\msvcp140-ef6047a69b174ada5cb2eff1d2bc9a62.dll'
# Consider using the `--user` option or check the permissions.

# %%
from skforecast.model_selection_statsmodels import grid_search_sarimax
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 from skforecast.model_selection_statsmodels import grid_search_sarimax
#
# ModuleNotFoundError: No module named 'skforecast'

# %%
print(results.summary())
# Out:
#                                        SARIMAX Results
# ...
# Dep. Variable:                                      y   No. Observations:                   81
# Model:             SARIMAX(1, 1, 1)x(1, 3, [1, 2], 7)   Log Likelihood                -198.004
# Date:                                Wed, 06 Mar 2024   AIC                            408.008
# Time:                                        11:31:54   BIC                            420.473
# Sample:                                    04-01-2022   HQIC                           412.873
#                                          - 06-20-2022
# Covariance Type:                                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5703      0.199      2.872      0.004       0.181       0.960
# ma.L1         -0.9433      0.303     -3.117      0.002      -1.536      -0.350
# ...

# %%
from sklearn.metrics import mean_squared_error

error = mean_squared_error(test_new, predictions)
print('Test MSE: %.5f' % error)
# Out:
# Test MSE: 87.74697

# %%
from sklearn.metrics import r2_score 

error = r2_score(test_new, predictions)
print('Test COD: %.5f' % error)
# Out:
# Test COD: 0.43378

# %%
plt.figure(figsize=(15, 6))
plt.plot(test_new, color = 'blue')
plt.plot(predictions, color = 'green')
plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.plot(test, color = 'blue')
plt.plot(predictions, color = 'green')
plt.show()

# %%
plt.figure(figsize=(25, 6))
plt.plot(product12, color = 'blue')
plt.plot(predictions, color = 'green')
plt.show()

# %%
predictions = results.predict(start='2022-06-30', end='2022-07-30')
plt.figure(figsize=(25, 6))
plt.plot(product12, color = 'blue')
plt.plot(predictions, color = 'green')
plt.show()

# %%
predictions = results.predict(start='2022-04-01', end='2022-06-30')
plt.figure(figsize=(25, 6))
plt.plot(product12, color = 'blue')
plt.plot(predictions, color = 'green')
plt.show()

# %%
predictions = results.predict(start='2022-04-01', end='2022-06-30')
plt.figure(figsize=(25, 6))
plt.plot(train_new, color = 'blue')
plt.plot(test_new, color = 'blue')
plt.plot(predictions, color = 'green')
plt.show()

# %%
predictions = results.predict(start='2022-04-01', end='2022-07-30')
plt.figure(figsize=(25, 6))
plt.plot(train_new, color = 'blue')
plt.plot(test_new, color = 'blue')
plt.plot(predictions, color = 'green')
plt.show()
